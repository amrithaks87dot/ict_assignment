# %% [markdown]
# <a href="https://colab.research.google.com/github/amrithaks87dot/ict_assignment/blob/main/PROJECT01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#QUESTION 8

Step 1: start
Step 2: Read a,b,c
Step 3: print a,b,c

# %%
##8
def int(self, course_id, name, credits, max_seats):
        self.course_id = course_id
        self.name = name
        self.credits = credits
        self.max_seats = max_seats
        self.seats_taken = 0
        self.students = []

print("Course and Student classes defined successfully.")
# Out:
# Course and Student classes defined successfully.

# %%
def int(self, transaction_id, account_number, transaction_type, amount, linked_account,datetime):
        self.transaction_id = transaction_id
        self.account_number = account_number
        self.type = transaction_type
        self.amount = amount
        self.timestamp = datetime.now()
        self.linked_account = linked_account
def str(self):
        if self.linked_account:
          return f("Transaction ID: {self.transaction_id}, Account: {self.account_number}, Type: {self.type}, Amount: {self.amount}, Linked Account: {self.linked_account}, Timestamp: {self.timestamp}")
          return f("Transaction ID: {self.transaction_id}, Account: {self.account_number}, Type: {self.type}, Amount: {self.amount}, Timestamp: {self.timestamp}")
